# %%
import os.path as op
import numpy as np
import string

from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score

#import nltk
from nltk import SnowballStemmer
from nltk import pos_tag

# %%
# Load data
print("Loading dataset")

from glob import glob
filenames_neg = sorted(glob(op.join('..', 'data', 'imdb1', 'neg', '*.txt')))
filenames_pos = sorted(glob(op.join('..', 'data', 'imdb1', 'pos', '*.txt')))
filenames_stop_words = sorted(glob(op.join('..','data','english.stop')))


stop_words_list = [open(f).read() for f in filenames_stop_words][0].split()

texts_neg = [open(f).read() for f in filenames_neg]
texts_pos = [open(f).read() for f in filenames_pos]
texts = texts_neg + texts_pos
y = np.ones(len(texts), dtype=np.int)
y[:len(texts_neg)] = 0.

print("%d documents" % len(texts))
print("punctuation = ", string.punctuation)
# Out:
# Loading dataset
# 2000 documents
# punctuation =  !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
### Preprocess

def text_process(texts, stem = False, tag = False):
    """
        Takes in a list of texts, then performs the following:
        1. Remove all punctuation for each text
        2. Remove all stopwords for each text
        3. Returns the cleaned texts
        
        if stem == True, change each word to its stem.
        if tag == True, we'll keep only noun, adverbs, verbs and adjectives.
    """
    cleaned_texts = []
    keep_cat = ['NN','ADV','VB','JJ']
    for text in texts :
        list_text = []
        # Check characters to see if they are in punctuation
        nopunc = [char for char in text if char not in string.punctuation]
    
        # Join the characters again to form the string.
        nopunc = ''.join(nopunc)
    
        # Now just remove any stopwords and stem words
        list_words = nopunc.split()
        if stem == False :
            if tag == False :
                list_text = [word for word in list_words if word.lower() not in stop_words_list] #Question 2
            else :
                for word in nopunc.split() :
                    print(pos_tag([stemmer.stem(word)]))
                list_text = [word for word in list_words if word.lower() not in stop_words_list] #Question 4
                #print(list_text)
        else :
            if tag == False :
                list_text = [stemmer.stem(word) for word in list_words if word.lower() not in stop_words_list] #Question 3
            else :
                list_text = [stemmer.stem(word) for word in list_words if (word.lower() not in stop_words_list and pos_tag([word])[0][1] not in keep_cat)] #Question 3
                
                    
        new_text = ' '.join(list_text)
        cleaned_texts.append(new_text)
       
    return cleaned_texts

# %%
stemmer = SnowballStemmer("english")
vectorizer = CountVectorizer()

# %%
texts_processed = text_process(texts, stem = False, tag = False)
X = vectorizer.fit_transform(texts_processed)

# %%
texts_processed_stem = text_process(texts, stem = True, tag = False)
X_stem = vectorizer.fit_transform(texts_processed_stem)

# %%
texts_processed_stem_tag = text_process(texts, stem = True, tag = True)
X_stem_tag = vectorizer.fit_transform(texts_processed_stem_tag)

# %%
print(X.shape)
print(X_stem.shape)
print(X_stem_tag.shape)
# Out:
# (2000, 47026)
# (2000, 31375)
# (2000, 12700)

# %%
#Naive Bayesien
from sklearn.naive_bayes import MultinomialNB
print("Testing Naive Bayesien with cross validation 5-folds: ")
 

clf = MultinomialNB()

print("Mean accuracy with no stem and no tag = {acc} %".format(acc = 100*cross_val_score(clf,X,y, cv = 5).mean()))

print("Mean accuracy with stem and no tag = {acc} %".format(acc = 100*cross_val_score(clf,X_stem,y, cv = 5).mean()))
   
print("Mean accuracy with stem and tag = {acc} %".format(acc = 100*cross_val_score(clf,X_stem_tag,y, cv = 5).mean()))
# Out:
# Testing Naive Bayesien with cross validation 5-folds:
# Mean accuracy with no stem and no tag = 80.74999999999999 %
# Mean accuracy with stem and no tag = 80.4 %
# Mean accuracy with stem and tag = 76.55000000000001 %

# %%
# Linear SVC
from sklearn.svm import LinearSVC
print("Testing Linear SVC : ")

for c in [0.1, 0.5, 1, 1.5, 3] :
    print("====== Testing for c = %f ======"%c)
    clf = LinearSVC(C = c)
    print("Mean accuracy with no stem and no tag = {acc} %".format(acc = 100*cross_val_score(clf,X,y, cv = 5).mean()))
    print("Mean accuracy with stem and no tag = {acc} %".format(acc = 100*cross_val_score(clf,X_stem,y, cv = 5).mean()))
    print("Mean accuracy with stem and tag = {acc} %".format(acc = 100*cross_val_score(clf,X_stem_tag,y, cv = 5).mean()))
# Out:
# Testing Linear SVC :
# ====== Testing for c = 0.100000 ======
# Mean accuracy with no stem and no tag = 82.5 %
# Mean accuracy with stem and no tag = 81.64999999999999 %
# Mean accuracy with stem and tag = 73.5 %
# ====== Testing for c = 0.500000 ======
# Mean accuracy with no stem and no tag = 82.4 %
# Mean accuracy with stem and no tag = 81.4 %
# Mean accuracy with stem and tag = 73.05 %
# ====== Testing for c = 1.000000 ======
# Mean accuracy with no stem and no tag = 82.25 %
# Mean accuracy with stem and no tag = 81.30000000000001 %
# Mean accuracy with stem and tag = 72.89999999999999 %
# ====== Testing for c = 1.500000 ======
# Mean accuracy with no stem and no tag = 82.15 %
# Mean accuracy with stem and no tag = 81.25 %
# Mean accuracy with stem and tag = 72.85000000000001 %
# ====== Testing for c = 3.000000 ======
# Mean accuracy with no stem and no tag = 82.2 %
# Mean accuracy with stem and no tag = 81.0 %
# Mean accuracy with stem and tag = 72.8 %

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
print("Testing LogisticRegression : ")
clf = LogisticRegression()
print("Mean accuracy with no stem and no tag = {acc} %".format(acc = 100*cross_val_score(clf,X,y, cv = 5).mean()))
print("Mean accuracy with stem and no tag = {acc} %".format(acc = 100*cross_val_score(clf,X_stem,y, cv = 5).mean()))   
print("Mean accuracy with stem and tag = {acc} %".format(acc = 100*cross_val_score(clf,X_stem_tag,y, cv = 5).mean()))
# Out:
# Testing LogisticRegression :
# Mean accuracy with no stem and no tag = 83.05 %
# Mean accuracy with stem and no tag = 82.5 %
# Mean accuracy with stem and tag = 74.85000000000001 %

# %%
# Gradient Boosting
from catboost import CatBoostClassifier
print("Testing catboost : ")
clf = CatBoostClassifier(max_depth = 5, loss_function = 'CrossEntropy', learning_rate = 0.4, n_estimators = 100, early_stopping_rounds = 10)
print("Mean accuracy with no stem and no tag = {acc} %".format(acc = 100*cross_val_score(clf,X.toarray(),list(y), cv = 5).mean()))
# Out:
# Testing catboost :
# 0:	learn: 0.6684747	total: 1.39s	remaining: 2m 17s
# 1:	learn: 0.6424381	total: 2.16s	remaining: 1m 45s
# 2:	learn: 0.6283759	total: 2.94s	remaining: 1m 35s
# 3:	learn: 0.6120352	total: 3.61s	remaining: 1m 26s
# 4:	learn: 0.5984274	total: 4.26s	remaining: 1m 20s
# 5:	learn: 0.5868165	total: 4.88s	remaining: 1m 16s
# 6:	learn: 0.5819870	total: 5.49s	remaining: 1m 13s
# 7:	learn: 0.5721067	total: 6.21s	remaining: 1m 11s
# 8:	learn: 0.5581243	total: 6.89s	remaining: 1m 9s
# 9:	learn: 0.5524790	total: 7.55s	remaining: 1m 7s
# 10:	learn: 0.5425520	total: 8.36s	remaining: 1m 7s
# 11:	learn: 0.5374270	total: 9.04s	remaining: 1m 6s
# 12:	learn: 0.5302918	total: 9.79s	remaining: 1m 5s
# 13:	learn: 0.5197620	total: 10.4s	remaining: 1m 4s
# 14:	learn: 0.5155247	total: 11s	remaining: 1m 2s
# 15:	learn: 0.5106465	total: 11.7s	remaining: 1m 1s
# 62:	learn: 0.2547655	total: 45.5s	remaining: 26.7s
# 63:	learn: 0.2532133	total: 46s	remaining: 25.9s
# 64:	learn: 0.2512954	total: 46.7s	remaining: 25.1s
# 65:	learn: 0.2499573	total: 47.4s	remaining: 24.4s
# 66:	learn: 0.2462821	total: 48.1s	remaining: 23.7s
# 67:	learn: 0.2454267	total: 48.7s	remaining: 22.9s
# 68:	learn: 0.2430993	total: 49.4s	remaining: 22.2s
# 69:	learn: 0.2415570	total: 50.1s	remaining: 21.5s
# 70:	learn: 0.2398205	total: 50.8s	remaining: 20.7s
# 71:	learn: 0.2360458	total: 51.4s	remaining: 20s
# 72:	learn: 0.2330051	total: 52.1s	remaining: 19.3s
# 73:	learn: 0.2321253	total: 52.8s	remaining: 18.5s
# 74:	learn: 0.2278213	total: 53.5s	remaining: 17.8s
# 75:	learn: 0.2263960	total: 54.1s	remaining: 17.1s
# 76:	learn: 0.2255254	total: 54.7s	remaining: 16.3s
# 77:	learn: 0.2212046	total: 55.3s	remaining: 15.6s
# 78:	learn: 0.2188028	total: 56s	remaining: 14.9s
# 79:	learn: 0.2167146	total: 56.7s	remaining: 14.2s
# 80:	learn: 0.2161038	total: 57.3s	remaining: 13.4s
# 81:	learn: 0.2135779	total: 57.9s	remaining: 12.7s
# 82:	learn: 0.2122979	total: 58.6s	remaining: 12s
# 83:	learn: 0.2114754	total: 59.3s	remaining: 11.3s
# 84:	learn: 0.2101235	total: 59.9s	remaining: 10.6s
# 85:	learn: 0.2069070	total: 1m	remaining: 9.86s
# 86:	learn: 0.2065174	total: 1m 1s	remaining: 9.13s
# 87:	learn: 0.2056946	total: 1m 1s	remaining: 8.42s
# 88:	learn: 0.2049069	total: 1m 2s	remaining: 7.72s
# 89:	learn: 0.2043132	total: 1m 3s	remaining: 7.02s
# 90:	learn: 0.2012287	total: 1m 3s	remaining: 6.31s
# 91:	learn: 0.1983482	total: 1m 4s	remaining: 5.62s
# 92:	learn: 0.1956207	total: 1m 5s	remaining: 4.92s
# 93:	learn: 0.1938072	total: 1m 5s	remaining: 4.21s
# 94:	learn: 0.1909900	total: 1m 6s	remaining: 3.51s
# 95:	learn: 0.1875582	total: 1m 7s	remaining: 2.81s
# 96:	learn: 0.1862398	total: 1m 8s	remaining: 2.11s
# 97:	learn: 0.1851575	total: 1m 8s	remaining: 1.41s
# 98:	learn: 0.1847185	total: 1m 9s	remaining: 706ms
# 99:	learn: 0.1839494	total: 1m 10s	remaining: 0us
# 0:	learn: 0.6452695	total: 1.5s	remaining: 2m 28s
# 1:	learn: 0.6266263	total: 2.18s	remaining: 1m 46s
# 2:	learn: 0.6106755	total: 2.8s	remaining: 1m 30s
# 3:	learn: 0.5913459	total: 3.38s	remaining: 1m 21s
# 4:	learn: 0.5739494	total: 4.05s	remaining: 1m 16s
# 5:	learn: 0.5660326	total: 4.9s	remaining: 1m 16s
# 6:	learn: 0.5557306	total: 5.48s	remaining: 1m 12s
# 7:	learn: 0.5427303	total: 6.27s	remaining: 1m 12s
# 8:	learn: 0.5321905	total: 7.07s	remaining: 1m 11s
# 9:	learn: 0.5180327	total: 7.82s	remaining: 1m 10s
# 10:	learn: 0.5137413	total: 8.55s	remaining: 1m 9s
# 59:	learn: 0.2570575	total: 41.6s	remaining: 27.8s
# 60:	learn: 0.2565283	total: 42.4s	remaining: 27.1s
# 61:	learn: 0.2534560	total: 43.2s	remaining: 26.5s
# 62:	learn: 0.2517045	total: 44s	remaining: 25.8s
# 63:	learn: 0.2479167	total: 44.9s	remaining: 25.2s
# 64:	learn: 0.2440400	total: 45.7s	remaining: 24.6s
# 65:	learn: 0.2407163	total: 46.4s	remaining: 23.9s
# 66:	learn: 0.2402399	total: 47s	remaining: 23.2s
# 67:	learn: 0.2350147	total: 47.7s	remaining: 22.5s
# 68:	learn: 0.2333002	total: 48.3s	remaining: 21.7s
# 69:	learn: 0.2303035	total: 49.1s	remaining: 21.1s
# 70:	learn: 0.2286503	total: 49.7s	remaining: 20.3s
# 71:	learn: 0.2277287	total: 50.5s	remaining: 19.6s
# 72:	learn: 0.2268076	total: 51.3s	remaining: 19s
# 73:	learn: 0.2227662	total: 52s	remaining: 18.3s
# 74:	learn: 0.2197884	total: 52.8s	remaining: 17.6s
# 75:	learn: 0.2159375	total: 53.6s	remaining: 16.9s
# 76:	learn: 0.2149804	total: 54.4s	remaining: 16.2s
# 77:	learn: 0.2137822	total: 55s	remaining: 15.5s
# 78:	learn: 0.2119070	total: 55.6s	remaining: 14.8s
# 79:	learn: 0.2106487	total: 56.4s	remaining: 14.1s
# 80:	learn: 0.2086233	total: 57.1s	remaining: 13.4s
# 81:	learn: 0.2068249	total: 57.9s	remaining: 12.7s
# 82:	learn: 0.2055908	total: 58.7s	remaining: 12s
# 83:	learn: 0.2045804	total: 59.5s	remaining: 11.3s
# 84:	learn: 0.2041018	total: 1m	remaining: 10.6s
# 85:	learn: 0.2005203	total: 1m 1s	remaining: 9.95s
# 86:	learn: 0.1993083	total: 1m 1s	remaining: 9.25s
# 87:	learn: 0.1988762	total: 1m 2s	remaining: 8.55s
# 88:	learn: 0.1985259	total: 1m 3s	remaining: 7.84s
# 89:	learn: 0.1955553	total: 1m 4s	remaining: 7.13s
# 90:	learn: 0.1941295	total: 1m 4s	remaining: 6.43s
# 91:	learn: 0.1937349	total: 1m 5s	remaining: 5.7s
# 92:	learn: 0.1929614	total: 1m 6s	remaining: 5s
# 93:	learn: 0.1903488	total: 1m 7s	remaining: 4.28s
# 94:	learn: 0.1888611	total: 1m 7s	remaining: 3.56s
# 95:	learn: 0.1881739	total: 1m 8s	remaining: 2.85s
# 96:	learn: 0.1872424	total: 1m 8s	remaining: 2.13s
# 97:	learn: 0.1867724	total: 1m 9s	remaining: 1.42s
# 98:	learn: 0.1859403	total: 1m 10s	remaining: 709ms
# 99:	learn: 0.1817395	total: 1m 10s	remaining: 0us
# 0:	learn: 0.6548540	total: 1.48s	remaining: 2m 26s
# 1:	learn: 0.6401803	total: 2.19s	remaining: 1m 47s
# 2:	learn: 0.6210755	total: 2.97s	remaining: 1m 36s
# 3:	learn: 0.6053544	total: 3.77s	remaining: 1m 30s
# 4:	learn: 0.5880279	total: 4.46s	remaining: 1m 24s
# 5:	learn: 0.5779448	total: 5.13s	remaining: 1m 20s
# 6:	learn: 0.5655890	total: 5.84s	remaining: 1m 17s
# 7:	learn: 0.5514900	total: 6.5s	remaining: 1m 14s
# 8:	learn: 0.5483480	total: 7.24s	remaining: 1m 13s
# 9:	learn: 0.5371088	total: 8.01s	remaining: 1m 12s
# 10:	learn: 0.5256277	total: 8.69s	remaining: 1m 10s
# 11:	learn: 0.5192012	total: 9.48s	remaining: 1m 9s
# 12:	learn: 0.5135275	total: 10.2s	remaining: 1m 8s
# 13:	learn: 0.5090246	total: 11s	remaining: 1m 7s
# 14:	learn: 0.4998447	total: 11.7s	remaining: 1m 6s
# 15:	learn: 0.4937755	total: 12.5s	remaining: 1m 5s
# 16:	learn: 0.4883338	total: 13.2s	remaining: 1m 4s
# 17:	learn: 0.4806500	total: 13.8s	remaining: 1m 2s
# 18:	learn: 0.4752368	total: 14.5s	remaining: 1m 1s
# 19:	learn: 0.4652746	total: 15.1s	remaining: 1m
# 20:	learn: 0.4570905	total: 15.7s	remaining: 59.1s
# 21:	learn: 0.4550539	total: 16.2s	remaining: 57.6s
# 22:	learn: 0.4461286	total: 16.9s	remaining: 56.7s
# 23:	learn: 0.4334377	total: 17.5s	remaining: 55.5s
# 24:	learn: 0.4223960	total: 18.3s	remaining: 54.8s
# 25:	learn: 0.4110480	total: 19s	remaining: 54s
# 26:	learn: 0.4013853	total: 19.6s	remaining: 53.1s
# 27:	learn: 0.3954669	total: 20.3s	remaining: 52.3s
# 28:	learn: 0.3809666	total: 21.1s	remaining: 51.7s
# 29:	learn: 0.3786347	total: 21.8s	remaining: 50.8s
# 30:	learn: 0.3714637	total: 22.4s	remaining: 50s
# 31:	learn: 0.3628323	total: 23.2s	remaining: 49.2s
# 32:	learn: 0.3565521	total: 23.8s	remaining: 48.4s
# 33:	learn: 0.3504441	total: 24.4s	remaining: 47.4s
# 34:	learn: 0.3454462	total: 25s	remaining: 46.4s
# 35:	learn: 0.3408817	total: 25.6s	remaining: 45.6s
# 36:	learn: 0.3396113	total: 26.3s	remaining: 44.8s
# 37:	learn: 0.3382656	total: 26.9s	remaining: 43.9s
# 38:	learn: 0.3366654	total: 27.6s	remaining: 43.2s
# 39:	learn: 0.3321549	total: 28.2s	remaining: 42.4s
# 40:	learn: 0.3261214	total: 28.9s	remaining: 41.5s
# 41:	learn: 0.3206507	total: 29.6s	remaining: 40.9s
# 42:	learn: 0.3141157	total: 30.2s	remaining: 40s
# 43:	learn: 0.3121350	total: 30.9s	remaining: 39.3s
# 44:	learn: 0.3076021	total: 31.5s	remaining: 38.5s
# 45:	learn: 0.2991818	total: 32.2s	remaining: 37.8s
# 46:	learn: 0.2959204	total: 32.8s	remaining: 36.9s
# 47:	learn: 0.2914441	total: 33.5s	remaining: 36.3s
# 48:	learn: 0.2867016	total: 34.2s	remaining: 35.6s
# 49:	learn: 0.2814223	total: 34.8s	remaining: 34.8s
# 50:	learn: 0.2772250	total: 35.6s	remaining: 34.2s
# 51:	learn: 0.2752509	total: 36.3s	remaining: 33.5s
# 52:	learn: 0.2743151	total: 36.9s	remaining: 32.8s
# 53:	learn: 0.2699875	total: 37.6s	remaining: 32s
# 54:	learn: 0.2634726	total: 38.2s	remaining: 31.3s
# 55:	learn: 0.2610547	total: 38.8s	remaining: 30.5s
# 56:	learn: 0.2603086	total: 39.5s	remaining: 29.8s
# 57:	learn: 0.2547474	total: 40.1s	remaining: 29.1s
# 58:	learn: 0.2513389	total: 40.8s	remaining: 28.4s
# 59:	learn: 0.2480330	total: 41.5s	remaining: 27.7s
# 60:	learn: 0.2463598	total: 42.1s	remaining: 26.9s
# 61:	learn: 0.2450777	total: 42.6s	remaining: 26.1s
# 62:	learn: 0.2439765	total: 43.3s	remaining: 25.4s
# 63:	learn: 0.2425017	total: 43.9s	remaining: 24.7s
# 64:	learn: 0.2402560	total: 44.6s	remaining: 24s
# 65:	learn: 0.2373901	total: 45.2s	remaining: 23.3s
# 66:	learn: 0.2369101	total: 45.9s	remaining: 22.6s
# 67:	learn: 0.2345072	total: 46.4s	remaining: 21.8s
# 68:	learn: 0.2336080	total: 47.1s	remaining: 21.2s
# 69:	learn: 0.2294286	total: 47.8s	remaining: 20.5s
# 70:	learn: 0.2291421	total: 48.3s	remaining: 19.7s
# 71:	learn: 0.2255042	total: 48.9s	remaining: 19s
# 72:	learn: 0.2221228	total: 49.8s	remaining: 18.4s
# 73:	learn: 0.2202053	total: 50.7s	remaining: 17.8s
# 74:	learn: 0.2184294	total: 51.7s	remaining: 17.2s
# 75:	learn: 0.2177377	total: 52.4s	remaining: 16.6s
# 76:	learn: 0.2145033	total: 53.5s	remaining: 16s
# 77:	learn: 0.2128377	total: 54.4s	remaining: 15.3s
# 78:	learn: 0.2112079	total: 55.4s	remaining: 14.7s
# 79:	learn: 0.2108939	total: 56.2s	remaining: 14s
# 80:	learn: 0.2105996	total: 56.8s	remaining: 13.3s
# 81:	learn: 0.2093016	total: 57.6s	remaining: 12.6s
# 82:	learn: 0.2062540	total: 58.5s	remaining: 12s
# 83:	learn: 0.2045606	total: 59.3s	remaining: 11.3s
# 84:	learn: 0.2037106	total: 1m	remaining: 10.6s
# 85:	learn: 0.2021654	total: 1m	remaining: 9.89s
# 86:	learn: 0.2015700	total: 1m 1s	remaining: 9.19s
# 87:	learn: 0.2006602	total: 1m 2s	remaining: 8.48s
# 88:	learn: 0.1995188	total: 1m 3s	remaining: 7.79s
# 89:	learn: 0.1978356	total: 1m 4s	remaining: 7.12s
# 90:	learn: 0.1958224	total: 1m 5s	remaining: 6.44s
# 91:	learn: 0.1947673	total: 1m 5s	remaining: 5.73s
# 92:	learn: 0.1935178	total: 1m 6s	remaining: 5.02s
# 93:	learn: 0.1918300	total: 1m 7s	remaining: 4.3s
# 94:	learn: 0.1913431	total: 1m 8s	remaining: 3.59s
# 95:	learn: 0.1901727	total: 1m 8s	remaining: 2.87s
# 96:	learn: 0.1870429	total: 1m 9s	remaining: 2.15s
# 97:	learn: 0.1861337	total: 1m 10s	remaining: 1.43s
# 98:	learn: 0.1839593	total: 1m 11s	remaining: 720ms
# 99:	learn: 0.1835626	total: 1m 11s	remaining: 0us
# 0:	learn: 0.6594412	total: 1.54s	remaining: 2m 32s
# 1:	learn: 0.6440958	total: 2.41s	remaining: 1m 58s
# 2:	learn: 0.6202701	total: 3.18s	remaining: 1m 42s
# 3:	learn: 0.6014323	total: 4.19s	remaining: 1m 40s
# 4:	learn: 0.5854230	total: 4.99s	remaining: 1m 34s
# 5:	learn: 0.5686187	total: 5.72s	remaining: 1m 29s
# 6:	learn: 0.5568901	total: 6.39s	remaining: 1m 24s
# 7:	learn: 0.5456463	total: 7.17s	remaining: 1m 22s
# 8:	learn: 0.5452267	total: 7.8s	remaining: 1m 18s
# 9:	learn: 0.5340273	total: 8.35s	remaining: 1m 15s
# 10:	learn: 0.5241630	total: 9.55s	remaining: 1m 17s
# 11:	learn: 0.5182309	total: 10.7s	remaining: 1m 18s
# 12:	learn: 0.5106282	total: 11.4s	remaining: 1m 16s
# 13:	learn: 0.5050956	total: 12.3s	remaining: 1m 15s
# 14:	learn: 0.5007615	total: 12.9s	remaining: 1m 13s
# 15:	learn: 0.4935379	total: 13.4s	remaining: 1m 10s
# 16:	learn: 0.4889408	total: 14.1s	remaining: 1m 8s
# 17:	learn: 0.4857414	total: 14.7s	remaining: 1m 7s
# 18:	learn: 0.4813454	total: 15.4s	remaining: 1m 5s
# 19:	learn: 0.4691618	total: 16.1s	remaining: 1m 4s
# 20:	learn: 0.4631817	total: 16.8s	remaining: 1m 3s
# 21:	learn: 0.4496265	total: 17.4s	remaining: 1m 1s
# 22:	learn: 0.4361031	total: 18.2s	remaining: 1m
# 23:	learn: 0.4265511	total: 18.9s	remaining: 59.9s
# 24:	learn: 0.4239565	total: 19.7s	remaining: 59.1s
# 25:	learn: 0.4191509	total: 20.3s	remaining: 57.8s
# 26:	learn: 0.4106409	total: 21s	remaining: 56.8s
# 27:	learn: 0.3985738	total: 21.7s	remaining: 55.7s
# 28:	learn: 0.3939398	total: 22.2s	remaining: 54.4s
# 29:	learn: 0.3929338	total: 22.7s	remaining: 53.1s
# 30:	learn: 0.3866065	total: 23.3s	remaining: 52s
# 31:	learn: 0.3856454	total: 24s	remaining: 50.9s
# 32:	learn: 0.3788910	total: 24.6s	remaining: 50s
# 33:	learn: 0.3767709	total: 25.2s	remaining: 49s
# 34:	learn: 0.3690930	total: 25.8s	remaining: 48s
# 35:	learn: 0.3614149	total: 26.4s	remaining: 47s
# 36:	learn: 0.3537035	total: 27.1s	remaining: 46.1s
# 37:	learn: 0.3519629	total: 27.7s	remaining: 45.2s
# 38:	learn: 0.3453304	total: 28.3s	remaining: 44.2s
# 39:	learn: 0.3397403	total: 29s	remaining: 43.4s
# 40:	learn: 0.3340883	total: 29.6s	remaining: 42.6s
# 41:	learn: 0.3279018	total: 30.3s	remaining: 41.8s
# 42:	learn: 0.3267579	total: 30.8s	remaining: 40.9s
# 43:	learn: 0.3232364	total: 31.4s	remaining: 40s
# 44:	learn: 0.3153633	total: 32s	remaining: 39.1s
# 45:	learn: 0.3113743	total: 32.6s	remaining: 38.3s
# 46:	learn: 0.3079267	total: 33.2s	remaining: 37.4s
# 47:	learn: 0.3038512	total: 33.7s	remaining: 36.6s
# 48:	learn: 0.3009664	total: 34.3s	remaining: 35.7s
# 49:	learn: 0.2993187	total: 34.9s	remaining: 34.9s
# 50:	learn: 0.2962526	total: 35.5s	remaining: 34.1s
# 51:	learn: 0.2949133	total: 36.1s	remaining: 33.4s
# 52:	learn: 0.2896912	total: 36.7s	remaining: 32.6s
# 53:	learn: 0.2842716	total: 37.4s	remaining: 31.9s
# 54:	learn: 0.2833968	total: 38s	remaining: 31.1s
# 55:	learn: 0.2782779	total: 38.6s	remaining: 30.3s
# 56:	learn: 0.2774807	total: 39.2s	remaining: 29.6s
# 57:	learn: 0.2751034	total: 40.5s	remaining: 29.4s
# 58:	learn: 0.2742382	total: 41.2s	remaining: 28.6s
# 59:	learn: 0.2738578	total: 42.3s	remaining: 28.2s
# 60:	learn: 0.2693132	total: 43.8s	remaining: 28s
# 61:	learn: 0.2663976	total: 45.3s	remaining: 27.7s
# 62:	learn: 0.2616306	total: 46.5s	remaining: 27.3s
# 63:	learn: 0.2551385	total: 48.2s	remaining: 27.1s
# 64:	learn: 0.2520033	total: 50.8s	remaining: 27.4s
# 65:	learn: 0.2509745	total: 55.7s	remaining: 28.7s
# 66:	learn: 0.2462156	total: 1m 9s	remaining: 34.3s
# 67:	learn: 0.2423965	total: 1m 16s	remaining: 36.2s
# 68:	learn: 0.2374218	total: 1m 18s	remaining: 35.4s
# 69:	learn: 0.2336762	total: 1m 19s	remaining: 34.3s
# 70:	learn: 0.2330853	total: 1m 20s	remaining: 33s
# 71:	learn: 0.2308449	total: 1m 22s	remaining: 31.9s
# 72:	learn: 0.2265980	total: 1m 24s	remaining: 31.1s
# 73:	learn: 0.2250145	total: 1m 26s	remaining: 30.3s
# 74:	learn: 0.2228514	total: 1m 28s	remaining: 29.5s
# 75:	learn: 0.2195166	total: 1m 29s	remaining: 28.1s
# 76:	learn: 0.2158278	total: 1m 29s	remaining: 26.8s
# 77:	learn: 0.2132020	total: 1m 30s	remaining: 25.5s
# 78:	learn: 0.2105918	total: 1m 31s	remaining: 24.3s
# 79:	learn: 0.2085520	total: 1m 32s	remaining: 23s
# 80:	learn: 0.2073863	total: 1m 32s	remaining: 21.8s
# 81:	learn: 0.2062284	total: 1m 33s	remaining: 20.6s
# 82:	learn: 0.2051580	total: 1m 34s	remaining: 19.4s
# 83:	learn: 0.2044111	total: 1m 35s	remaining: 18.3s
# 84:	learn: 0.2008597	total: 1m 36s	remaining: 17.1s
# 85:	learn: 0.1981259	total: 1m 37s	remaining: 15.9s
# 86:	learn: 0.1962429	total: 1m 38s	remaining: 14.7s
# 87:	learn: 0.1932555	total: 1m 39s	remaining: 13.6s
# 88:	learn: 0.1914235	total: 1m 40s	remaining: 12.4s
# 89:	learn: 0.1892403	total: 1m 41s	remaining: 11.3s
# 90:	learn: 0.1883797	total: 1m 42s	remaining: 10.1s
# 91:	learn: 0.1873010	total: 1m 43s	remaining: 8.97s
# 92:	learn: 0.1870717	total: 1m 43s	remaining: 7.83s
# 93:	learn: 0.1864175	total: 1m 44s	remaining: 6.69s
# 94:	learn: 0.1854578	total: 1m 45s	remaining: 5.55s
# 95:	learn: 0.1845976	total: 1m 46s	remaining: 4.43s
# 96:	learn: 0.1839029	total: 1m 46s	remaining: 3.31s
# 97:	learn: 0.1834249	total: 1m 47s	remaining: 2.19s
# 98:	learn: 0.1831782	total: 1m 48s	remaining: 1.09s
# 99:	learn: 0.1829576	total: 1m 48s	remaining: 0us
# Mean accuracy with no stem and no tag = 78.60000000000001 %
